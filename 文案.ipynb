# %%
from __future__ import print_function, absolute_import
from gm.api import *
from gm.model.storage import context
from gm.model import DictLikeAlgoOrder
from gm.pb.account_pb2 import AlgoOrder
import numpy as np
import pandas as pd
from datetime import  datetime,timezone, timedelta
import datetime
from sklearn import svm

#set_token('807b8ba88782d7343bfe3ad918f33f93a2610ee8')
set_token('c6ed6b1252a6bf9b594592708d5e30389b84334b')
account_id='d5f9a8c4-4a94-11f0-a85d-00163e022aa6'  #证券24h 
account_id='c347715a-4a94-11f0-a85d-00163e022aa6'  #24H期货
account_id_国投='db9caf2a-5014-11f0-bfb8-00163e022aa6'
pd.set_option('display.max_columns', None)  
#pd.set_option('display.max_rows', None)
#pd.DataFrame()
#df = pd.read_excel('____.xlsx')
#df.to_excel('filenamed.xlsx', index=False)
# coding=utf-8

# %% [markdown]
# # 综合排名

# %% [markdown]
# [](attachment:656a7659-60fa-4c16-8e6e-f07b2517328f.png)
# <img src="attachment:656a7659-60fa-4c16-8e6e-f07b2517328f.png" alt="" style="zoom:50%;" />

# %% [markdown]
# | |基本栏目| | |资金栏目| |
# |---|:---:|---|---|:---:|---|
# |今涨|快涨|委比|入资|资速|换手|
# |今跌|快跌|~委比|大宗入资|大宗流速|净买率|
# |今振|量比|成交额|非大宗入资|非大宗流速|净卖率|

# %% [markdown]
# #  竞价分析

# %% [markdown]
# [](attachment:c55533e3-9a69-4db0-8d99-f24d18df7dd8.png)
# <img src="attachment:c55533e3-9a69-4db0-8d99-f24d18df7dd8.png" alt="" style="zoom:50%;" />

# %% [markdown]
# 大盘竞价|板块热门预测
# |---|:---:|
# 竞价时序|个股具体

# %% [markdown]
# # 数据/综合看盘

# %% [markdown]
# [](attachment:b2611a5e-4878-4255-9433-624549da207b.png)
# <img src="attachment:b2611a5e-4878-4255-9433-624549da207b.png" alt="" style="zoom:50%;" />

# %% [markdown]
# ||数据看盘||
# |:---:|:---:|:---:|
# |综合强度评分|上证|涨跌个数统计|
# |打版|赚钱效益|两融|
# |破高|热门100|新增人数|

# %% [markdown]
# [](attachment:34522b18-0605-4289-bfc5-2197b35d16a3.png)
# <img src="attachment:34522b18-0605-4289-bfc5-2197b35d16a3.png" alt="" style="zoom:50%;" />

# %% [markdown]
# # 今日关注/近期热点（板块）

# %% [markdown]
# [](attachment:88fdc5db-c52c-45ef-b8bf-2bec2a231477.png)
# <img src="attachment:88fdc5db-c52c-45ef-b8bf-2bec2a231477.png" alt="" style="zoom:50%" />

# %% [markdown]
# [](attachment:3c716c0d-4a09-404e-943b-41c7b6893ee8.png)
# <img src="attachment:3c716c0d-4a09-404e-943b-41c7b6893ee8.png" alt="" style="zoom:50%" />
